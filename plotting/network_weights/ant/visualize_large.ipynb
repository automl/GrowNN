# %%
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
import torch
from typing import Dict
import os
from stable_baselines3.common.save_util import load_from_zip_file
from utils.plotting import set_rc_params

# %%
os.getcwd()
# Out:
# '/Users/######/Desktop/###/clean-stuff/GrowNN'

# %%
set_rc_params()
# remove grid 
plt.rcParams['axes.grid'] = False

# %% [markdown]
# # Net2DeeperNet Depth 8

# %%
base_path = "smac3_output/###_growing_nn_new_seeded/ant_net2deeper/22/(32, 0.2, None, 9.853902629348276e-05, 0.95, 0.00014592877169397115, 0.5, 5, 2048, True, 0.001, 0.99)/8/0/model"
data, params, pytorch_variables = load_from_zip_file(base_path) 

# loda

# %%
params["policy"].keys()
# Out:
# odict_keys(['log_std', 'features_extractor.input_layer.weight', 'features_extractor.input_layer.bias', 'features_extractor.net2deeper_network.sequential_container.0.weight', 'features_extractor.net2deeper_network.sequential_container.0.bias', 'features_extractor.net2deeper_network.sequential_container.2.weight', 'features_extractor.net2deeper_network.sequential_container.2.bias', 'features_extractor.net2deeper_network.sequential_container.4.weight', 'features_extractor.net2deeper_network.sequential_container.4.bias', 'features_extractor.net2deeper_network.sequential_container.6.weight', 'features_extractor.net2deeper_network.sequential_container.6.bias', 'features_extractor.net2deeper_network.sequential_container.8.weight', 'features_extractor.net2deeper_network.sequential_container.8.bias', 'features_extractor.net2deeper_network.sequential_container.10.weight', 'features_extractor.net2deeper_network.sequential_container.10.bias', 'features_extractor.net2deeper_network.sequential_container.12.weight', 'features_extractor.net2deeper_network.sequential_container.12.bias', 'features_extractor.net2deeper_network.sequential_container.14.weight', 'features_extractor.net2deeper_network.sequential_container.14.bias', 'pi_features_extractor.input_layer.weight', 'pi_features_extractor.input_layer.bias', 'pi_features_extractor.net2deeper_network.sequential_container.0.weight', 'pi_features_extractor.net2deeper_network.sequential_container.0.bias', 'pi_features_extractor.net2deeper_network.sequential_container.2.weight', 'pi_features_extractor.net2deeper_network.sequential_container.2.bias', 'pi_features_extractor.net2deeper_network.sequential_container.4.weight', 'pi_features_extractor.net2deeper_network.sequential_container.4.bias', 'pi_features_extractor.net2deeper_network.sequential_container.6.weight', 'pi_features_extractor.net2deeper_network.sequential_container.6.bias', 'pi_features_extractor.net2deeper_network.sequential_container.8.weight', 'pi_features_extractor.net2deeper_network.sequential_container.8.bias', 'pi_features_extractor.net2deeper_network.sequential_container.10.weight', 'pi_features_extractor.net2deeper_network.sequential_container.10.bias', 'pi_features_extractor.net2deeper_network.sequential_container.12.weight', 'pi_features_extractor.net2deeper_network.sequential_container.12.bias', 'pi_features_extractor.net2deeper_network.sequential_container.14.weight', 'pi_features_extractor.net2deeper_network.sequential_container.14.bias', 'vf_features_extractor.input_layer.weight', 'vf_features_extractor.input_layer.bias', 'vf_features_extractor.net2deeper_network.sequential_container.0.weight', 'vf_features_extractor.net2deeper_network.sequential_container.0.bias', 'vf_features_extractor.net2deeper_network.sequential_container.2.weight', 'vf_features_extractor.net2deeper_network.sequential_container.2.bias', 'vf_features_extractor.net2deeper_network.sequential_container.4.weight', 'vf_features_extractor.net2deeper_network.sequential_container.4.bias', 'vf_features_extractor.net2deeper_network.sequential_container.6.weight', 'vf_features_extractor.net2deeper_network.sequential_container.6.bias', 'vf_features_extractor.net2deeper_network.sequential_container.8.weight', 'vf_features_extractor.net2deeper_network.sequential_container.8.bias', 'vf_features_extractor.net2deeper_network.sequential_container.10.weight', 'vf_features_extractor.net2deeper_network.sequential_container.10.bias', 'vf_features_extractor.net2deeper_network.sequential_container.12.weight', 'vf_features_extractor.net2deeper_network.sequential_container.12.bias', 'vf_features_extractor.net2deeper_network.sequential_container.14.weight', 'vf_features_extractor.net2deeper_network.sequential_container.14.bias', 'mlp_extractor.policy_net.0.weight', 'mlp_extractor.policy_net.0.bias', 'mlp_extractor.value_net.0.weight', 'mlp_extractor.value_net.0.bias', 'action_net.weight', 'action_net.bias', 'value_net.weight', 'value_net.bias'])

# %%
# First layer weights
first_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.0.weight"]
first_layer_weights = np.abs(first_layer_weights)
first_layer_weights = first_layer_weights
# Second layer weights
second_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.2.weight"]
second_layer_weights = np.abs(second_layer_weights)
second_layer_weights = second_layer_weights
# third layer weights
third_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.4.weight"]
third_layer_weights = np.abs(third_layer_weights)
third_layer_weights = third_layer_weights
# fourth layer weights
fourth_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.6.weight"]
fourth_layer_weights = np.abs(fourth_layer_weights)
fourth_layer_weights = fourth_layer_weights
# fifth layer weights
fifth_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.8.weight"]
fifth_layer_weights = np.abs(fifth_layer_weights)
fifth_layer_weights = fifth_layer_weights
# sixth layer weights
sixth_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.10.weight"]
sixth_layer_weights = np.abs(sixth_layer_weights)
sixth_layer_weights = sixth_layer_weights
# seventh layer weights
seventh_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.12.weight"]
seventh_layer_weights = np.abs(seventh_layer_weights)
seventh_layer_weights = seventh_layer_weights
# eighth layer weights
eighth_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.14.weight"]
eighth_layer_weights = np.abs(eighth_layer_weights)
eighth_layer_weights = eighth_layer_weights

# %%
import matplotlib.pyplot as plt

# Create a subplot layout with 3 columns for horizontal arrangement
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
axs = axs.flatten()

# First layer weights
im0 = axs[0].imshow(first_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[0].set_title('First Layer', fontsize=22)

# Second layer weights
im1 = axs[1].imshow(second_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[1].set_title('Second Layer', fontsize=22)

# Third layer weights
im2 = axs[2].imshow(third_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[2].set_title('Third Layer', fontsize=22)

# Fourth layer weights
im3 = axs[3].imshow(fourth_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[3].set_title('Fourth Layer', fontsize=22)

# Fifth layer weights
im4 = axs[4].imshow(fifth_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[4].set_title('Fifth Layer', fontsize=22)

# Sixth layer weights
im5 = axs[5].imshow(sixth_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[5].set_title('Sixth Layer', fontsize=22)

# Seventh layer weights
im6 = axs[6].imshow(seventh_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[6].set_title('Seventh Layer', fontsize=22)

# Eighth layer weights
im7 = axs[7].imshow(eighth_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[7].set_title('Eighth Layer', fontsize=22)

# Hide the last empty subplot (axs[8]) if only 8 layers are used
fig.delaxes(axs[8])

# Add colorbar
fig.colorbar(im3, ax=axs[:8], orientation='vertical', fraction=0.02, pad=0.04)

# Save figure
plt.savefig('plotting/network_weights/ant/weights_8.pdf', bbox_inches='tight')

# %% [markdown]
# # Ant Net2Deeper Depth 4

# %%
base_path = 'smac3_output/###_growing_nn_new_seeded/ant_net2deeper/9/(256, 0.2, None, 0.0028277130573217566, 0.95, 0.00016765626422149914, 0.5, 12, 2048, True, 0.001, 0.99)/4/0/model'
data, params, pytorch_variables = load_from_zip_file(base_path)

# %%
first_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.0.weight"]
first_layer_weights = np.abs(first_layer_weights)
first_layer_weights = first_layer_weights
# Second layer weights
second_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.2.weight"]
second_layer_weights = np.abs(second_layer_weights)
second_layer_weights = second_layer_weights
# third layer weights
third_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.4.weight"]
third_layer_weights = np.abs(third_layer_weights)
third_layer_weights = third_layer_weights
# fourth layer weights
fourth_layer_weights = params["policy"]["features_extractor.net2deeper_network.sequential_container.6.weight"]
fourth_layer_weights = np.abs(fourth_layer_weights)
fourth_layer_weights = fourth_layer_weights

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
# First layer weights
im0 = axs[0, 0].imshow(first_layer_weights, cmap='viridis', vmin = 0, vmax = 1.3)
axs[0, 0].set_title('First Layer', fontsize=28)

# Second layer weights
im1 = axs[0, 1].imshow(second_layer_weights, cmap='viridis', vmin = 0, vmax = 1.3)
axs[0, 1].set_title('Second Layer', fontsize=28)

# Third layer weights
im2 = axs[1, 0].imshow(third_layer_weights, cmap='viridis', vmin = 0, vmax = 1.3)
axs[1, 0].set_title('Third Layer', fontsize=28)

# Fourth layer weights
im3 = axs[1, 1].imshow(fourth_layer_weights, cmap='viridis', vmin = 0, vmax = 1.3)
axs[1, 1].set_title('Fourth Layer', fontsize=28)

# Add colorbar for axs[2]
fig.colorbar(im3, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)
plt.savefig('plotting/network_weights/ant/weights_4.pdf', bbox_inches='tight')
