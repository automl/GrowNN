# %%
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
import torch
from typing import Dict
import os
from stable_baselines3.common.save_util import load_from_zip_file

# %%
# plt increase xticks and yticks font size\
plt.rcParams.update({'font.size': 15})

# %% [markdown]
# # Net2DeeperNet Depth 2 Random

# %%
base_path = "###_growing_nn_new_seeded/increase_difficulty_n2d/1/(128, 0.2, None, 0.0014141531903114589, 0.95, 0.0007349477632031754, 0.5, 5, 2048, False, 0.5, 512, 1, 512, 2)/2/0/model.zip"
data, params, pytorch_variables = load_from_zip_file(base_path) 
# loda

# %%
params["policy"].keys()
# Out:
# odict_keys(['features_extractor.extractors.chars.1.weight', 'features_extractor.extractors.chars.1.bias', 'features_extractor.downscaling.0.weight', 'features_extractor.downscaling.0.bias', 'features_extractor.linear_layers.sequential_container.0.weight', 'features_extractor.linear_layers.sequential_container.0.bias', 'features_extractor.linear_layers.sequential_container.2.weight', 'features_extractor.linear_layers.sequential_container.2.bias', 'pi_features_extractor.extractors.chars.1.weight', 'pi_features_extractor.extractors.chars.1.bias', 'pi_features_extractor.downscaling.0.weight', 'pi_features_extractor.downscaling.0.bias', 'pi_features_extractor.linear_layers.sequential_container.0.weight', 'pi_features_extractor.linear_layers.sequential_container.0.bias', 'pi_features_extractor.linear_layers.sequential_container.2.weight', 'pi_features_extractor.linear_layers.sequential_container.2.bias', 'vf_features_extractor.extractors.chars.1.weight', 'vf_features_extractor.extractors.c
# ...

# %%
# First layer weights
first_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.0.weight"]
first_layer_weights = np.abs(first_layer_weights)
# Select only 100 x 100 weights
first_layer_weights = first_layer_weights[:50, :50]
# Second layer weights
second_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.2.weight"]
second_layer_weights = np.abs(second_layer_weights)
# Select only 100 x 100 weights
second_layer_weights = second_layer_weights[:50, :50]

# %%
# Subplot with 3 figures horically
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
# First layer weights
axs[0].imshow(first_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[0].set_title('Initial Layer Weights', fontsize=17)
# Second layer weights
im3 = axs[1].imshow(second_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[1].set_title('Layer two Weights', fontsize=17)
# Add colorbar for axs[2]
fig.colorbar(im3, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)
plt.suptitle('Depth 2; Difficulty Increased after Depth 1', fontsize=19, fontweight='bold')
plt.savefig('plotting/network_weights/minihack/difficulty_increases/2_mid.png', bbox_inches='tight')

# %% [markdown]
# # Net2DeeperNet Depth 4 Mid

# %%
base_path = "###_growing_nn_new_seeded/increase_difficulty_n2d/2/(32, 0.2, None, 0.0043118389770875785, 0.95, 0.00013659088002690003, 0.5, 9, 2048, False, 0.5, 512, 1, 512, 2)/4/0/model.zip"
data, params, pytorch_variables = load_from_zip_file(base_path)

# %%
params["policy"].keys()
# Out:
# odict_keys(['features_extractor.extractors.chars.1.weight', 'features_extractor.extractors.chars.1.bias', 'features_extractor.downscaling.0.weight', 'features_extractor.downscaling.0.bias', 'features_extractor.linear_layers.sequential_container.0.weight', 'features_extractor.linear_layers.sequential_container.0.bias', 'features_extractor.linear_layers.sequential_container.2.weight', 'features_extractor.linear_layers.sequential_container.2.bias', 'features_extractor.linear_layers.sequential_container.4.weight', 'features_extractor.linear_layers.sequential_container.4.bias', 'features_extractor.linear_layers.sequential_container.6.weight', 'features_extractor.linear_layers.sequential_container.6.bias', 'pi_features_extractor.extractors.chars.1.weight', 'pi_features_extractor.extractors.chars.1.bias', 'pi_features_extractor.downscaling.0.weight', 'pi_features_extractor.downscaling.0.bias', 'pi_features_extractor.linear_layers.sequential_container.0.weight', 'pi_features_extractor.linear
# ...

# %%
# First layer weights
first_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.0.weight"]
first_layer_weights = np.abs(first_layer_weights)
# Select only 100 x 100 weights
first_layer_weights = first_layer_weights[:50, :50]
# Second layer weights
second_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.2.weight"]
second_layer_weights = np.abs(second_layer_weights)
# Select only 100 x 100 weights
second_layer_weights = second_layer_weights[:50, :50]
# Third layer weights
third_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.4.weight"]
third_layer_weights = np.abs(third_layer_weights)
# Select only 100 x 100 weights
third_layer_weights = third_layer_weights[:50, :50]
# Fourth layer weights
fourth_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.6.weight"]
fourth_layer_weights = np.abs(fourth_layer_weights)
# Select only 100 x 100 weights
fourth_layer_weights = fourth_layer_weights[:50, :50]

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# First layer weights
axs[0, 0].imshow(first_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[0, 0].set_title('Initial Layer Weights', fontsize=17)
# Second layer weights
axs[0, 1].imshow(second_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[0, 1].set_title('Layer two Weights', fontsize=17)
# Third layer weights
axs[1, 0].imshow(third_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[1, 0].set_title('Layer three Weights', fontsize=17)
# Fourth layer weights
im4 = axs[1, 1].imshow(fourth_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[1, 1].set_title('Layer four Weights', fontsize=17)
# Add colorbar for axs[2]
fig.colorbar(im4, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)
plt.suptitle('Depth 4; Difficulty Increased after Depth 2', fontsize=19, fontweight='bold')
plt.savefig('plotting/network_weights/minihack/difficulty_increases/4_mid.png', bbox_inches='tight')

# %% [markdown]
# # Net2DeeperNet Depth 4 End

# %%
base_path = "###_growing_nn_new_seeded/increase_difficulty_n2d/4/(256, 0.2, None, 0.0005309372850206717, 0.95, 0.00018756031479505173, 0.5, 15, 2048, False, 0.5, 512, 1, 512, 2)/4/0/model.zip"
data, params, pytorch_variables = load_from_zip_file(base_path)

# %%
params["policy"].keys()
# Out:
# odict_keys(['features_extractor.extractors.chars.1.weight', 'features_extractor.extractors.chars.1.bias', 'features_extractor.downscaling.0.weight', 'features_extractor.downscaling.0.bias', 'features_extractor.linear_layers.sequential_container.0.weight', 'features_extractor.linear_layers.sequential_container.0.bias', 'features_extractor.linear_layers.sequential_container.2.weight', 'features_extractor.linear_layers.sequential_container.2.bias', 'features_extractor.linear_layers.sequential_container.4.weight', 'features_extractor.linear_layers.sequential_container.4.bias', 'features_extractor.linear_layers.sequential_container.6.weight', 'features_extractor.linear_layers.sequential_container.6.bias', 'pi_features_extractor.extractors.chars.1.weight', 'pi_features_extractor.extractors.chars.1.bias', 'pi_features_extractor.downscaling.0.weight', 'pi_features_extractor.downscaling.0.bias', 'pi_features_extractor.linear_layers.sequential_container.0.weight', 'pi_features_extractor.linear
# ...

# %%
# First layer weights
first_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.0.weight"]
first_layer_weights = np.abs(first_layer_weights)
# Select only 100 x 100 weights
first_layer_weights = first_layer_weights[:50, :50]
# Second layer weights
second_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.2.weight"]
second_layer_weights = np.abs(second_layer_weights)
# Select only 100 x 100 weights
second_layer_weights = second_layer_weights[:50, :50]
# Third layer weights
third_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.4.weight"]
third_layer_weights = np.abs(third_layer_weights)
# Select only 100 x 100 weights
third_layer_weights = third_layer_weights[:50, :50]
# Fourth layer weights
fourth_layer_weights = params["policy"]["features_extractor.linear_layers.sequential_container.6.weight"]
fourth_layer_weights = np.abs(fourth_layer_weights)
# Select only 100 x 100 weights
fourth_layer_weights = fourth_layer_weights[:50, :50]

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# First layer weights
axs[0, 0].imshow(first_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[0, 0].set_title('Initial Layer Weights', fontsize=17)
# Second layer weights
axs[0, 1].imshow(second_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[0, 1].set_title('Layer two Weights', fontsize=17)
# Third layer weights
axs[1, 0].imshow(third_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[1, 0].set_title('Layer three Weights', fontsize=17)
# Fourth layer weights
im4 = axs[1, 1].imshow(fourth_layer_weights, cmap='viridis', vmin=0, vmax=1.3)
axs[1, 1].set_title('Layer four Weights', fontsize=17)
# Add colorbar for axs[2]
fig.colorbar(im4, ax=axs, orientation='vertical', fraction=0.02, pad=0.04)
plt.suptitle('Depth 4; Difficulty Increased after Depth 3', fontsize=19, fontweight='bold')
plt.savefig('plotting/network_weights/minihack/difficulty_increases/4_end.png', bbox_inches='tight')
